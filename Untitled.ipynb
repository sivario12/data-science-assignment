# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn import metrics

# %%
cd = pd.read_csv("Company_Data.csv")

# %%
cd
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
label_encoder = preprocessing.LabelEncoder()
cd['ShelveLoc'] = label_encoder.fit_transform(cd['ShelveLoc'])
cd['Urban'] = label_encoder.fit_transform(cd['Urban'])
cd['US'] = label_encoder.fit_transform(cd['US'])

# %%
cd.sample(10)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 381   3.90        124      65           21         496    151          0   77
# 121  11.67        125      89           10         380     87          0   28
# 294  12.66        148      76            3         126     99          1   60
# 63    8.47        119      88           10         170    101          2   61
# 391   6.10        153      63            0          49    124          0   56
# 359   3.13        130      62           11         396    130          0   66
# 5    10.81        124     113           13         501     72          0   78
# 380   9.64        106      64           10          17     89          2   68
# 204   8.74        155      80            0         237    124          2   37
# 239   3.89        123     105            0         149    118          0   62
#
#      Education  Urban  US
# 381         13      1   1
# 121         10      1   1
# 294         11      1   1
# 63          13      1   1
# 391         16      1   0
# 359         14      1   1
# 5           16      0   1
# 380         17      1   1
# 204         14      1   0
# 239         16      1   1

# %%
x = cd.iloc[:,1:]
y = cd['Sales']
y
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
# Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
model = DecisionTreeRegressor(max_depth=5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
#Find the mse
from sklearn import metrics
pred=model.predict(X_test)
metrics.mean_squared_error(y_test,pred)
# Out:
# 4.317457905333609

# %%
metrics.mean_absolute_percentage_error(y_test,pred)
# Out:
# 0.24786039267171112

# %%
np.mean(np.abs(y_test-pred)/np.array(y_test))
# Out:
# 0.24786039267171117

# %%
tree.plot_tree(model)
# Out:
# [Text(0.49353448275862066, 0.9166666666666666, 'X[5] <= 0.5\nsquared_error = 8.614\nsamples = 268\nvalue = 7.399'),
#  Text(0.2629310344827586, 0.75, 'X[4] <= 102.5\nsquared_error = 5.749\nsamples = 69\nvalue = 5.189'),
#  Text(0.13793103448275862, 0.5833333333333334, 'X[1] <= 42.0\nsquared_error = 4.453\nsamples = 19\nvalue = 7.277'),
#  Text(0.06896551724137931, 0.4166666666666667, 'X[6] <= 57.5\nsquared_error = 3.045\nsamples = 5\nvalue = 5.158'),
#  Text(0.034482758620689655, 0.25, 'X[4] <= 86.5\nsquared_error = 0.168\nsamples = 2\nvalue = 7.09'),
#  Text(0.017241379310344827, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 6.68'),
#  Text(0.05172413793103448, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.10344827586206896, 0.25, 'X[4] <= 95.0\nsquared_error = 0.815\nsamples = 3\nvalue = 3.87'),
#  Text(0.08620689655172414, 0.08333333333333333, 'squared_error = 0.051\nsamples = 2\nvalue = 3.245'),
#  Text(0.1206896551724138, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 5.12'),
#  Text(0.20689655172413793, 0.4166666666666667, 'X[4] <= 88.0\nsquared_error = 2.779\nsamples = 14\nvalue = 8.034'),
#  Text(0.1724137931034483, 0.25, 'X[3] <= 312.5\nsquared_error = 2.313\nsamples = 4\nvalue = 9.753'),
#  Text(0.15517241379310345, 0.08333333333333333, 'squared_error = 0.016\nsamples = 2\nvalue = 8.265'),
#  Text(0.1896551724137931, 0.08333333333333333, 'squared_error = 0.185\nsamples = 2\nvalue = 11.24'),
#  Text(0.2413793103448276, 0.25, 'X[4] <= 96.5\nsquared_error = 1.312\nsamples = 10\nvalue = 7.347'),
#  Text(0.22413793103448276, 0.08333333333333333, 'squared_error = 1.342\nsamples = 5\nvalue = 6.634'),
#  Text(0.25862068965517243, 0.08333333333333333, 'squared_error = 0.266\nsamples = 5\nvalue = 8.06'),
#  Text(0.3879310344827586, 0.5833333333333334, 'X[1] <= 115.5\nsquared_error = 3.954\nsamples = 50\nvalue = 4.396'),
#  Text(0.3448275862068966, 0.4166666666666667, 'X[0] <= 151.0\nsquared_error = 3.283\nsamples = 48\nvalue = 4.226'),
#  Text(0.3103448275862069, 0.25, 'X[3] <= 171.5\nsquared_error = 2.853\nsamples = 45\nvalue = 4.031'),
#  Text(0.29310344827586204, 0.08333333333333333, 'squared_error = 2.639\nsamples = 20\nvalue = 3.232'),
#  Text(0.3275862068965517, 0.08333333333333333, 'squared_error = 2.105\nsamples = 25\nvalue = 4.67'),
#  Text(0.3793103448275862, 0.25, 'X[6] <= 47.5\nsquared_error = 0.59\nsamples = 3\nvalue = 7.153'),
#  Text(0.3620689655172414, 0.08333333333333333, 'squared_error = 0.053\nsamples = 2\nvalue = 7.68'),
#  Text(0.39655172413793105, 0.08333333333333333, 'squared_error = -0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.43103448275862066, 0.4166666666666667, 'X[4] <= 124.0\nsquared_error = 2.789\nsamples = 2\nvalue = 8.47'),
#  Text(0.41379310344827586, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 10.14'),
#  Text(0.4482758620689655, 0.25, 'squared_error = -0.0\nsamples = 1\nvalue = 6.8'),
#  Text(0.7241379310344828, 0.75, 'X[5] <= 1.5\nsquared_error = 7.327\nsamples = 199\nvalue = 8.165'),
#  Text(0.5862068965517241, 0.5833333333333334, 'X[4] <= 135.0\nsquared_error = 6.225\nsamples = 57\nvalue = 10.265'),
#  Text(0.5172413793103449, 0.4166666666666667, 'X[0] <= 135.0\nsquared_error = 4.27\nsamples = 47\nvalue = 10.92'),
#  Text(0.4827586206896552, 0.25, 'X[4] <= 107.5\nsquared_error = 3.291\nsamples = 37\nvalue = 10.366'),
#  Text(0.46551724137931033, 0.08333333333333333, 'squared_error = 1.572\nsamples = 16\nvalue = 11.443'),
#  Text(0.5, 0.08333333333333333, 'squared_error = 3.043\nsamples = 21\nvalue = 9.545'),
#  Text(0.5517241379310345, 0.25, 'X[4] <= 94.0\nsquared_error = 2.547\nsamples = 10\nvalue = 12.971'),
#  Text(0.5344827586206896, 0.08333333333333333, 'squared_error = 0.469\nsamples = 2\nvalue = 15.585'),
#  Text(0.5689655172413793, 0.08333333333333333, 'squared_error = 0.931\nsamples = 8\nvalue = 12.318'),
#  Text(0.6551724137931034, 0.4166666666666667, 'X[7] <= 13.0\nsquared_error = 3.921\nsamples = 10\nvalue = 7.186'),
#  Text(0.6206896551724138, 0.25, 'X[4] <= 147.5\nsquared_error = 2.026\nsamples = 3\nvalue = 5.137'),
#  Text(0.603448275862069, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 7.02'),
#  Text(0.6379310344827587, 0.08333333333333333, 'squared_error = 0.378\nsamples = 2\nvalue = 4.195'),
#  Text(0.6896551724137931, 0.25, 'X[1] <= 46.0\nsquared_error = 2.162\nsamples = 7\nvalue = 8.064'),
#  Text(0.6724137931034483, 0.08333333333333333, 'squared_error = 0.16\nsamples = 4\nvalue = 6.88'),
#  Text(0.7068965517241379, 0.08333333333333333, 'squared_error = 0.467\nsamples = 3\nvalue = 9.643'),
#  Text(0.8620689655172413, 0.5833333333333334, 'X[4] <= 96.5\nsquared_error = 5.289\nsamples = 142\nvalue = 7.322'),
#  Text(0.7931034482758621, 0.4166666666666667, 'X[6] <= 50.5\nsquared_error = 3.329\nsamples = 26\nvalue = 9.793'),
#  Text(0.7586206896551724, 0.25, 'X[6] <= 38.5\nsquared_error = 1.363\nsamples = 11\nvalue = 10.934'),
#  Text(0.7413793103448276, 0.08333333333333333, 'squared_error = 1.179\nsamples = 5\nvalue = 11.598'),
#  Text(0.7758620689655172, 0.08333333333333333, 'squared_error = 0.842\nsamples = 6\nvalue = 10.38'),
#  Text(0.8275862068965517, 0.25, 'X[0] <= 89.0\nsquared_error = 3.116\nsamples = 15\nvalue = 8.957'),
#  Text(0.8103448275862069, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 4.16'),
#  Text(0.8448275862068966, 0.08333333333333333, 'squared_error = 1.578\nsamples = 14\nvalue = 9.299'),
#  Text(0.9310344827586207, 0.4166666666666667, 'X[2] <= 6.5\nsquared_error = 4.054\nsamples = 116\nvalue = 6.769'),
#  Text(0.896551724137931, 0.25, 'X[4] <= 127.0\nsquared_error = 3.932\nsamples = 66\nvalue = 6.058'),
#  Text(0.8793103448275862, 0.08333333333333333, 'squared_error = 2.102\nsamples = 42\nvalue = 6.672'),
#  Text(0.9137931034482759, 0.08333333333333333, 'squared_error = 5.319\nsamples = 24\nvalue = 4.983'),
#  Text(0.9655172413793104, 0.25, 'X[4] <= 123.5\nsquared_error = 2.669\nsamples = 50\nvalue = 7.706'),
#  Text(0.9482758620689655, 0.08333333333333333, 'squared_error = 1.742\nsamples = 29\nvalue = 8.452'),
#  Text(0.9827586206896551, 0.08333333333333333, 'squared_error = 2.119\nsamples = 21\nvalue = 6.676')]

# %%
cd.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
fn=['CompPrice', 'Income', 'Advertising', 'Population', 'Price','ShelveLoc', 'Age', 'Education', 'Urban', 'US']
cn=['Sales']
fig, axes = plt.subplots(figsize = (4,4), dpi=300)
tree.plot_tree(model,
               feature_names = fn, 
               class_names=cn,
               filled = True);
