# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D00D-676E
#
#  Directory of C:\Users\priya\Downloads\ASSIGNMENT SOLUTION\Multi Linear Regression
#
# 07/12/2022  18:26    <DIR>          .
# 07/12/2022  16:46    <DIR>          ..
# 07/12/2022  16:32    <DIR>          .ipynb_checkpoints
# 06/12/2022  22:21             2,440 50_Startups.csv
# 07/12/2022  16:43           558,082 50_Startups.ipynb
# 10/11/2022  23:00               468 proble_statement(50_startups).txt
# 10/11/2022  23:00             1,752 Toyota Corolla.txt
# 07/12/2022  16:40           224,041 ToyotaCorolla.csv
# 07/12/2022  18:26            23,059 ToyotaCorolla.ipynb
#                6 File(s)        809,842 bytes
#                3 Dir(s)  31,420,071,936 bytes free

# %%
import pandas as pd
toyota = pd.read_csv('ToyotaCorolla.csv',encoding='unicode_escape')
toyota
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
t_new = toyota[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
t_new
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
t_new.rename(columns = {'Age_08_04':'Age'},inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_20656\1191565446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_new.rename(columns = {'Age_08_04':'Age'},inplace=True)

# %%
t_new
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500   69  20544   86  1300      3      5             69    1025
# 1432  10845   72  19000   86  1300      3      5             69    1015
# 1433   8500   71  17016   86  1300      3      5             69    1015
# 1434   7250   70  16916   86  1300      3      5             69    1015
# 1435   6950   76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
t_new.corr()
# Out:
#                   Price       Age        KM        HP        cc     Doors  \
# Price          1.000000 -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age           -0.876590  1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960  0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990 -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389 -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326 -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104 -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197 -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198 -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age           -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
t_new.drop_duplicates()
# Out:
#       Price  Age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500   23  46986   90  2000      3      5            210    1165
# 1     13750   23  72937   90  2000      3      5            210    1165
# 2     13950   24  41711   90  2000      3      5            210    1165
# 3     14950   26  48000   90  2000      3      5            210    1165
# 4     13750   30  38500   90  2000      3      5            210    1170
# ...     ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500   69  20544   86  1300      3      5             69    1025
# 1432  10845   72  19000   86  1300      3      5             69    1015
# 1433   8500   71  17016   86  1300      3      5             69    1015
# 1434   7250   70  16916   86  1300      3      5             69    1015
# 1435   6950   76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %%
t_new.isna().sum()
# Out:
# Price            0
# Age              0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
sns.heatmap(t_new.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set_style(style='darkgrid')
sns.pairplot(t_new)

# %%
t_new.columns
# Out:
# Index(['Price', 'Age', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Quarterly_Tax',
#        'Weight'],
#       dtype='object')

# %%
import statsmodels.formula.api as smf
model = smf.ols("Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=t_new).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     1131.
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):               0.00
# Time:                        14:57:13   Log-Likelihood:                -12376.
# No. Observations:                1436   AIC:                         2.477e+04
# Df Residuals:                    1427   BIC:                         2.482e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#claculating VIF values

rqs_age = smf.ols("Age~KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=t_new).fit().rsquared
vif_age = 1/(1-rqs_age)

rqs_km = smf.ols("KM~Age+HP+cc+Doors+Gears+Quarterly_Tax+Weight",data=t_new).fit().rsquared
vif_km = 1/(1-rqs_km)

rqs_hp = smf.ols("HP~Age+KM+cc+Doors+Gears+Quarterly_Tax+Weight",data=t_new).fit().rsquared
vif_hp = 1/(1-rqs_hp)

rqs_cc = smf.ols("cc~Age+KM+HP+Doors+Gears+Quarterly_Tax+Weight",data=t_new).fit().rsquared
vif_cc = 1/(1-rqs_cc)

rqs_Doors = smf.ols("Doors~Age+KM+HP+cc+Gears+Quarterly_Tax+Weight",data=t_new).fit().rsquared
vif_Doors = 1/(1-rqs_Doors)

rqs_Gears = smf.ols("Gears~Age+KM+HP+cc+Doors+Quarterly_Tax+Weight",data=t_new).fit().rsquared
vif_Gears = 1/(1-rqs_Gears)

rqs_qt = smf.ols("Quarterly_Tax~Age+KM+HP+cc+Doors+Gears+Weight",data=t_new).fit().rsquared
vif_qt = 1/(1-rqs_qt)

rqs_wt = smf.ols("Weight~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax",data=t_new).fit().rsquared
vif_wt = 1/(1-rqs_wt)

vif_hp
# Out:
# 1.4194221086310974

# %%
d1 = {'variables':['Age', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Quarterly_Tax',
       'Weight'],
      'vif':[vif_age,vif_km,vif_hp,vif_cc,vif_Doors,vif_Gears,vif_qt,vif_wt]}
vif_frame = pd.DataFrame(d1)
vif_frame
# Out:
#        variables       vif
# 0            Age  1.884620
# 1             KM  1.756905
# 2             HP  1.419422
# 3             cc  1.163894
# 4          Doors  1.156575
# 5          Gears  1.098723
# 6  Quarterly_Tax  2.311431
# 7         Weight  2.516420

# %% [markdown]
# # Test for Normality of residuals

# %%
plt.hist(model.resid,bins = 20)
import statsmodels.api as sm
qqplot = sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %% [markdown]
# # Residual plot for homoscedasticity

# %%
def get_standardized_values(vals):
    return(vals-vals.mean())/vals.std()

plt.scatter(get_standardized_values(model.fittedvalues),
           get_standardized_values(model.resid))
plt.title("Residual Plot")
plt.show()

# %%
t_new.columns
# Out:
# Index(['Price', 'Age', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Quarterly_Tax',
#        'Weight'],
#       dtype='object')

# %% [markdown]
# # Residual VS Regressors

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"Age",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"KM",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"HP",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"cc",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"Doors",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"Gears",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"Quarterly_Tax",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"Weight",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Cook's Dsitance

# %%
model_influence = model.get_influence()
(c,_) = model_influence.cooks_distance
k = 8
n = 1436
3*(k+1)/n
# Out:
# 0.018802228412256268

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(t_new)),np.round(c,3))
plt.xlabel('Row index')
plt.ylabel('cooks distance')
plt.show()

# %%
np.where(c>0.018)
# Out:
# (array([  14,   16,   49,   80,  109,  110,  111,  141,  191,  192,  221,
#          523,  601,  654,  960,  991, 1058], dtype=int64),)

# %%
t_new1 = t_new.drop(t_new.index[[14,16,49,80,109,110,111,141,191,192,221,
         523,601,654,960,991,1058]],axis = 0).reset_index()

# %%
t_new1
# Out:
#       index  Price  Age     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0         0  13500   23  46986   90  2000      3      5            210    1165
# 1         1  13750   23  72937   90  2000      3      5            210    1165
# 2         2  13950   24  41711   90  2000      3      5            210    1165
# 3         3  14950   26  48000   90  2000      3      5            210    1165
# 4         4  13750   30  38500   90  2000      3      5            210    1170
# ...     ...    ...  ...    ...  ...   ...    ...    ...            ...     ...
# 1414   1431   7500   69  20544   86  1300      3      5             69    1025
# 1415   1432  10845   72  19000   86  1300      3      5             69    1015
# 1416   1433   8500   71  17016   86  1300      3      5             69    1015
# 1417   1434   7250   70  16916   86  1300      3      5             69    1015
# 1418   1435   6950   76      1  110  1600      5      5             19    1114
#
# ...

# %%
t_new1 = t_new1.drop(['index'],axis=1)

# %% [markdown]
# # Build Model

# %%
final_model = smf.ols('Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=t_new1).fit()

# %%
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.887
# Method:                 Least Squares   F-statistic:                     1393.
# Date:                Thu, 08 Dec 2022   Prob (F-statistic):               0.00
# Time:                        14:56:38   Log-Likelihood:                -12015.
# No. Observations:                1419   AIC:                         2.405e+04
# Df Residuals:                    1410   BIC:                         2.410e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
final_model.predict(t_new1[['Age', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Quarterly_Tax',
       'Weight']])
# Out:
# 0       16310.888673
# 1       15857.336139
# 2       16291.658688
# 3       15958.899033
# 4       15836.323468
#             ...
# 1414     9182.068160
# 1415     8560.624043
# 1416     8706.721503
# 1417     8819.891793
# 1418    10878.107228
# Length: 1419, dtype: float64
